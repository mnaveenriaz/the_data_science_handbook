# %% [markdown]
# # Viewing Internal Variables

# %%
# Set display of Notebook to Full Size
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# will give you the list of in scope variables:
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_2',
#  '_3',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'quit']

# %%
# will give you a dictionary of global variables
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '# Viewing Internal Variables\n#dir()  # will give you the list of in scope variables:\n#globals() # will give you a dictionary of global variables\n#locals() # will give you a dictionary of local variables',
#   '# Viewing Internal Variables\ndir()  # will give you the list of in scope variables:\n#globals() # will give you a dictionary of global variables\n#locals() # will give you a dictionary of local variables',
#   '# will give you the list of in scope variables:\ndir()',
#   '# will give you the list of in scope variables:\ndir()',
#   '# Set display of notebook to \njt -t oceans16 -f roboto -fs 12 -cellw 100%',
#   '# Set display of notebook to \nfrom IPython.core.display import display, HTML\ndisplay(HTML("<style>.container { width:100% !important; }</style>"))',
#   '# will give you a dictionary of global variables\nglobals()'],
#  '_oh': {2: ['In',
#    'Out',
#    '_',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_i',
#    '_i1',
#    '_i2',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    'exit',
#    'get_ipython',
#    'quit'],
#   3: ['In',
#    'Out',
#    '_',
#    '_2',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_i',
#    '_i1',
#    '_i2',
#    '_i3',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    'exit',
#    'get_ipython',
#    'quit'],
#   4: ['In',
#    'Out',
#    '_',
#    '_2',
#    '_3',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_i',
#    '_i1',
#    '_i2',
#    '_i3',
#    '_i4',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    'exit',
#    'get_ipython',
#    'quit']},
#  '_dh': ['/Users/naveenriaz/workspace/python/test/NoteBooks/Data Science Handbook Examples'],
#  'In': ['',
#   '# Viewing Internal Variables\n#dir()  # will give you the list of in scope variables:\n#globals() # will give you a dictionary of global variables\n#locals() # will give you a dictionary of local variables',
#   '# Viewing Internal Variables\ndir()  # will give you the list of in scope variables:\n#globals() # will give you a dictionary of global variables\n#locals() # will give you a dictionary of local variables',
#   '# will give you the list of in scope variables:\ndir()',
#   '# will give you the list of in scope variables:\ndir()',
#   '# Set display of notebook to \njt -t oceans16 -f roboto -fs 12 -cellw 100%',
#   '# Set display of notebook to \nfrom IPython.core.display import display, HTML\ndisplay(HTML("<style>.container { width:100% !important; }</style>"))',
#   '# will give you a dictionary of global variables\nglobals()'],
#  'Out': {2: ['In',
#    'Out',
#    '_',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_i',
#    '_i1',
#    '_i2',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    'exit',
#    'get_ipython',
#    'quit'],
#   3: ['In',
#    'Out',
#    '_',
#    '_2',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_i',
#    '_i1',
#    '_i2',
#    '_i3',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    'exit',
#    'get_ipython',
#    'quit'],
#   4: ['In',
#    'Out',
#    '_',
#    '_2',
#    '_3',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_i',
#    '_i1',
#    '_i2',
#    '_i3',
#    '_i4',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    'exit',
#    'get_ipython',
#    'quit']},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10cb94fd0>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10e2217f0>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10e2217f0>,
#  '_': ['In',
#   'Out',
#   '_',
#   '_2',
#   '_3',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_i',
#   '_i1',
#   '_i2',
#   '_i3',
#   '_i4',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   'exit',
#   'get_ipython',
#   'quit'],
#  '__': ['In',
#   'Out',
#   '_',
#   '_2',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_i',
#   '_i1',
#   '_i2',
#   '_i3',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   'exit',
#   'get_ipython',
#   'quit'],
#  '___': ['In',
#   'Out',
#   '_',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_i',
#   '_i1',
#   '_i2',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   'exit',
#   'get_ipython',
#   'quit'],
#  '_i': '# Set display of notebook to \nfrom IPython.core.display import display, HTML\ndisplay(HTML("<style>.container { width:100% !important; }</style>"))',
#  '_ii': '# Set display of notebook to \njt -t oceans16 -f roboto -fs 12 -cellw 100%',
#  '_iii': '# will give you the list of in scope variables:\ndir()',
#  '_i1': '# Viewing Internal Variables\n#dir()  # will give you the list of in scope variables:\n#globals() # will give you a dictionary of global variables\n#locals() # will give you a dictionary of local variables',
#  '_i2': '# Viewing Internal Variables\ndir()  # will give you the list of in scope variables:\n#globals() # will give you a dictionary of global variables\n#locals() # will give you a dictionary of local variables',
#  '_2': ['In',
#   'Out',
#   '_',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_i',
#   '_i1',
#   '_i2',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   'exit',
#   'get_ipython',
#   'quit'],
#  '_i3': '# will give you the list of in scope variables:\ndir()',
#  '_3': ['In',
#   'Out',
#   '_',
#   '_2',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_i',
#   '_i1',
#   '_i2',
#   '_i3',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   'exit',
#   'get_ipython',
#   'quit'],
#  '_i4': '# will give you the list of in scope variables:\ndir()',
#  '_4': ['In',
#   'Out',
#   '_',
#   '_2',
#   '_3',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_i',
#   '_i1',
#   '_i2',
#   '_i3',
#   '_i4',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   'exit',
#   'get_ipython',
#   'quit'],
#  '_i5': '# Set display of notebook to \njt -t oceans16 -f roboto -fs 12 -cellw 100%',
#  '_i6': '# Set display of notebook to \nfrom IPython.core.display import display, HTML\ndisplay(HTML("<style>.container { width:100% !important; }</style>"))',
#  'display': <function IPython.core.display.display(*objs, include=None, exclude=None, metadata=None, transient=None, display_id=None, **kwargs)>,
#  'HTML': IPython.core.display.HTML,
#  '_i7': '# will give you a dictionary of global variables\nglobals()'}

# %%
# will give you a dictionary of local variables
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '# Viewing Internal Variables\n#dir()  # will give you the list of in scope variables:\n#globals() # will give you a dictionary of global variables\n#locals() # will give you a dictionary of local variables',
#   '# Viewing Internal Variables\ndir()  # will give you the list of in scope variables:\n#globals() # will give you a dictionary of global variables\n#locals() # will give you a dictionary of local variables',
#   '# will give you the list of in scope variables:\ndir()',
#   '# will give you the list of in scope variables:\ndir()',
#   '# Set display of notebook to \njt -t oceans16 -f roboto -fs 12 -cellw 100%',
#   '# Set display of notebook to \nfrom IPython.core.display import display, HTML\ndisplay(HTML("<style>.container { width:100% !important; }</style>"))',
#   '# will give you a dictionary of global variables\nglobals()',
#   '# will give you a dictionary of local variables\nlocals()'],
#  '_oh': {2: ['In',
#    'Out',
#    '_',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_i',
#    '_i1',
#    '_i2',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    'exit',
#    'get_ipython',
#    'quit'],
#   3: ['In',
#    'Out',
#    '_',
#    '_2',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_i',
#    '_i1',
#    '_i2',
#    '_i3',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    'exit',
#    'get_ipython',
#    'quit'],
#   4: ['In',
#    'Out',
#    '_',
#    '_2',
#    '_3',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_i',
#    '_i1',
#    '_i2',
#    '_i3',
#    '_i4',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    'exit',
#    'get_ipython',
#    'quit'],
#   7: {...}},
#  '_dh': ['/Users/naveenriaz/workspace/python/test/NoteBooks/Data Science Handbook Examples'],
#  'In': ['',
#   '# Viewing Internal Variables\n#dir()  # will give you the list of in scope variables:\n#globals() # will give you a dictionary of global variables\n#locals() # will give you a dictionary of local variables',
#   '# Viewing Internal Variables\ndir()  # will give you the list of in scope variables:\n#globals() # will give you a dictionary of global variables\n#locals() # will give you a dictionary of local variables',
#   '# will give you the list of in scope variables:\ndir()',
#   '# will give you the list of in scope variables:\ndir()',
#   '# Set display of notebook to \njt -t oceans16 -f roboto -fs 12 -cellw 100%',
#   '# Set display of notebook to \nfrom IPython.core.display import display, HTML\ndisplay(HTML("<style>.container { width:100% !important; }</style>"))',
#   '# will give you a dictionary of global variables\nglobals()',
#   '# will give you a dictionary of local variables\nlocals()'],
#  'Out': {2: ['In',
#    'Out',
#    '_',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_i',
#    '_i1',
#    '_i2',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    'exit',
#    'get_ipython',
#    'quit'],
#   3: ['In',
#    'Out',
#    '_',
#    '_2',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_i',
#    '_i1',
#    '_i2',
#    '_i3',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    'exit',
#    'get_ipython',
#    'quit'],
#   4: ['In',
#    'Out',
#    '_',
#    '_2',
#    '_3',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_i',
#    '_i1',
#    '_i2',
#    '_i3',
#    '_i4',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    'exit',
#    'get_ipython',
#    'quit'],
#   7: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10cb94fd0>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10e2217f0>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10e2217f0>,
#  '_': {...},
#  '__': ['In',
#   'Out',
#   '_',
#   '_2',
#   '_3',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_i',
#   '_i1',
#   '_i2',
#   '_i3',
#   '_i4',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   'exit',
#   'get_ipython',
#   'quit'],
#  '___': ['In',
#   'Out',
#   '_',
#   '_2',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_i',
#   '_i1',
#   '_i2',
#   '_i3',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   'exit',
#   'get_ipython',
#   'quit'],
#  '_i': '# will give you a dictionary of global variables\nglobals()',
#  '_ii': '# Set display of notebook to \nfrom IPython.core.display import display, HTML\ndisplay(HTML("<style>.container { width:100% !important; }</style>"))',
#  '_iii': '# Set display of notebook to \njt -t oceans16 -f roboto -fs 12 -cellw 100%',
#  '_i1': '# Viewing Internal Variables\n#dir()  # will give you the list of in scope variables:\n#globals() # will give you a dictionary of global variables\n#locals() # will give you a dictionary of local variables',
#  '_i2': '# Viewing Internal Variables\ndir()  # will give you the list of in scope variables:\n#globals() # will give you a dictionary of global variables\n#locals() # will give you a dictionary of local variables',
#  '_2': ['In',
#   'Out',
#   '_',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_i',
#   '_i1',
#   '_i2',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   'exit',
#   'get_ipython',
#   'quit'],
#  '_i3': '# will give you the list of in scope variables:\ndir()',
#  '_3': ['In',
#   'Out',
#   '_',
#   '_2',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_i',
#   '_i1',
#   '_i2',
#   '_i3',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   'exit',
#   'get_ipython',
#   'quit'],
#  '_i4': '# will give you the list of in scope variables:\ndir()',
#  '_4': ['In',
#   'Out',
#   '_',
#   '_2',
#   '_3',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_i',
#   '_i1',
#   '_i2',
#   '_i3',
#   '_i4',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   'exit',
#   'get_ipython',
#   'quit'],
#  '_i5': '# Set display of notebook to \njt -t oceans16 -f roboto -fs 12 -cellw 100%',
#  '_i6': '# Set display of notebook to \nfrom IPython.core.display import display, HTML\ndisplay(HTML("<style>.container { width:100% !important; }</style>"))',
#  'display': <function IPython.core.display.display(*objs, include=None, exclude=None, metadata=None, transient=None, display_id=None, **kwargs)>,
#  'HTML': IPython.core.display.HTML,
#  '_i7': '# will give you a dictionary of global variables\nglobals()',
#  '_7': {...},
#  '_i8': '# will give you a dictionary of local variables\nlocals()'}
